# %%
from pymongo import MongoClient
config = {
  'host': '13.57.109.83:27017',
  'username': 'mongo_user',
  'password': '',
  'authSource': 'project4'
}

client = MongoClient(**config)

db = client.project4

# %%
db.job.find()

# %%
db.list_collection_names()
# Out:
# ['job']

# %%
cursor = db.job.find({}, {'_id':0, 'text': 1})
list(cursor)
# Out:
# [{'text': 'server tacolici palo alto part time tacolici first palo alto store open recent hire love taco love work restaur serv food drink custom profession manner act cashier need clean dine space train new staff'},
# ...
